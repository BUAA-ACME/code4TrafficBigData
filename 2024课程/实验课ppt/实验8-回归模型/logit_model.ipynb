# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

df = pd.read_csv('A4_AccidentCount.csv')
df['is_acc'] = df['AccCount'] > 0
df['is_acc'] = df['is_acc'].astype(int)
df.head()
# Out:
#    Link_ID  ST_MP  Length  NLane  LaneWidth  LShoulderWidth  RShoulderWidth  \
# 0        1   0.00    0.07      1         12              10               4
# 1        2   0.24    0.19      1         12              10               4
# 2        3   0.43    0.04      1         12              10               4
# 3        4   0.50    0.07      1         12              10               4
# 4        5   0.04    0.35      1         12              10               4
#
#    AADT  AccCount  RouteNo  is_acc
# 0  6225        10        5       1
# 1  6225         2        5       1
# 2  6225         0        5       0
# 3  6225         2        5       1
# 4  9147         2        5       1

# %%
model = smf.logit(
    'is_acc~ST_MP+Length+NLane+LaneWidth+LShoulderWidth+RShoulderWidth+AADT',
    data=df)
result = model.fit()
print(result.summary())
print('AIC:', result.aic)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.493817
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 is_acc   No. Observations:                 4752
# Model:                          Logit   Df Residuals:                     4744
# Method:                           MLE   Df Model:                            7
# Date:                Thu, 27 Apr 2023   Pseudo R-squ.:                  0.1905
# Time:                        16:47:52   Log-Likelihood:                -2346.6
# converged:                       True   LL-Null:                       -2898.9
# Covariance Type:            nonrobust   LLR p-value:                2.980e-234
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -1.1322      0.591     -1.916      0.055      -2.290       0.026
# ST_MP             -0.0012      0.000     -2.498      0.012      -0.002      -0.000
# Length             8.3670      0.493     16.969      0.000       7.401       9.333
# NLane              0.1320      0.033      3.963      0.000       0.067       0.197
# LaneWidth          0.0122      0.051      0.241      0.809      -0.087       0.111
# LShoulderWidth    -0.0142      0.012     -1.171      0.242      -0.038       0.010
# RShoulderWidth    -0.0126      0.011     -1.098      0.272      -0.035       0.010
# AADT            1.643e-05   1.39e-06     11.861      0.000    1.37e-05    1.91e-05
# ==================================================================================
# AIC: 4709.234545704392

# %%
model = smf.logit(
    'is_acc~ST_MP+Length+NLane+AADT',
    data=df)
result = model.fit()
print(result.summary())
print('AIC:', result.aic)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.494320
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 is_acc   No. Observations:                 4752
# Model:                          Logit   Df Residuals:                     4747
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 27 Apr 2023   Pseudo R-squ.:                  0.1897
# Time:                        16:48:27   Log-Likelihood:                -2349.0
# converged:                       True   LL-Null:                       -2898.9
# Covariance Type:            nonrobust   LLR p-value:                8.274e-237
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0821      0.108    -10.037      0.000      -1.293      -0.871
# ST_MP         -0.0014      0.000     -3.014      0.003      -0.002      -0.001
# Length         8.2903      0.488     16.990      0.000       7.334       9.247
# NLane          0.1284      0.032      3.960      0.000       0.065       0.192
# AADT        1.613e-05   1.34e-06     12.051      0.000    1.35e-05    1.88e-05
# ==============================================================================
# AIC: 4708.015730851663
